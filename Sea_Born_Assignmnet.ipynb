# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(df.survived, bins=20)
plt.show()
# Out:
# C:\Users\Munish\AppData\Local\Temp\ipykernel_7864\391450299.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.survived, bins=20)

# %%
sns.distplot(df.age, bins=20)
plt.show()
# Out:
# C:\Users\Munish\AppData\Local\Temp\ipykernel_7864\584206833.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.age, bins=20)

# %%
sns.distplot(df.fare, bins=20)
plt.show()
# Out:
# C:\Users\Munish\AppData\Local\Temp\ipykernel_7864\4038528503.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.fare, bins=20)

# %%
sns.distplot(df.pclass, bins=20)
plt.show()
# Out:
# C:\Users\Munish\AppData\Local\Temp\ipykernel_7864\1060819546.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.pclass, bins=20)

# %%
sns.kdeplot(df.pclass)
plt.show()

# %%
sns.kdeplot(df.fare)
plt.show()

# %%
sns.kdeplot(df.age)
plt.show()

# %%
sns.kdeplot(df.survived)
plt.show()

# %%
sns.scatterplot(x=df.survived, y=df.age)
plt.show()

# %%
sns.scatterplot(x=df.fare, y=df.pclass)
plt.show()

# %%
sns.scatterplot(x=df.survived, y=df.age, hue='class', data=df)
plt.show()

# %%
sns.scatterplot(x=df.fare, y=df.pclass, hue='sex', data=df)
plt.show()

# %%
sns.jointplot(x=df.survived, y=df.age, kind='kde')
plt.show()

# %%
sns.jointplot(x=df.fare, y=df.pclass, kind='kde')
plt.show()

# %%
sns.jointplot(x=df.survived, y=df.age, kind='hist')
plt.show()

# %%
sns.jointplot(x=df.fare, y=df.pclass, kind='hist')
plt.show()

# %%
sns.jointplot(x=df.survived, y=df.age, kind='reg')
plt.show()

# %%
sns.jointplot(x=df.fare, y=df.pclass, kind='reg')
plt.show()

# %%
sns.jointplot(x=df.survived, y=df.age, kind='resid')
plt.show()

# %%
sns.jointplot(x=df.fare, y=df.pclass, kind='resid')
plt.show()

# %%
sns.jointplot(x=df.survived, y=df.age, kind='hex')
plt.show()

# %%
sns.jointplot(x=df.fare, y=df.pclass, kind='hex')
plt.show()

# %%
sns.pairplot(data=df, hue='embark_town')
plt.show()

# %%
sns.countplot(x=df.sex)
plt.show()

# %%
sns.countplot(x=df.pclass)
plt.show()

# %%
sns.countplot(x=df.embark_town)
plt.show()

# %%
sns.countplot(x=df.alone)
plt.show()

# %%
sns.countplot(x=df.embarked)
plt.show()

# %%
sns.countplot(x=df.age)
plt.show()

# %%
sns.countplot(x=df.survived)
plt.show()

# %%
sns.boxenplot(x='sex', y='age', data=df)
plt.show()

# %%
sns.boxplot(x='embark_town', y='age', data=df)
plt.show()

# %%
sns.violinplot(x='embark_town', y='survived', data=df)
plt.show()

# %%
sns.violinplot(x='sex', y='age', data=df)
plt.show()

# %%
df.corr()
# Out:
# C:\Users\Munish\AppData\Local\Temp\ipykernel_7864\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# ...

# %%
sns.scatterplot(x='survived', y='age', data=df)
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, cmap='icefire_r')
plt.show()
# Out:
# C:\Users\Munish\AppData\Local\Temp\ipykernel_7864\2178647465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='icefire_r')

# %%
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 
# ...
